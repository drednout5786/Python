# %% [markdown]
# # Курс
#
# # Программирование на Python
#
# https://stepik.org/lesson/6433/step/1?unit=1240

# %% [markdown]
# # 3.4 Файловый ввод/вывод
#
# # Задача 1
#
# Напишите программу, которая считывает текст из файла (в файле может быть больше одной строки) и выводит самое частое слово в этом тексте и через пробел то, сколько раз оно встретилось. Если таких слов несколько, вывести лексикографически первое (можно использовать оператор < для строк).
#
# Слова, написанные в разных регистрах, считаются одинаковыми.
#
# Sample Input:
#
# abc a bCd bC AbC BC BCD bcd ABC
#
# Sample Output:
#
# abc 3

# %%
import fileinput
from collections import Counter
  
c = Counter(word for line in fileinput.input(files=('dataset_3363_3.txt')) for word in line.casefold().split())
max_count = max(c.values())
f1 = open("1.txt", "w+")
print(*min(p for p in c.items() if p[1] == max_count), file = f1)
f1.close()

# %% [markdown]
# # Задача 2
#
# Имеется файл с данными по успеваемости абитуриентов. Он представляет из себя набор строк, где в каждой строке записана следующая информация:
#
# Фамилия;Оценка_по_математике;Оценка_по_физике;Оценка_по_русскому_языку
#
# Поля внутри строки разделены точкой с запятой, оценки — целые числа.
#
# Напишите программу, которая считывает файл с подобной структурой и для каждого абитуриента выводит его среднюю оценку по этим трём предметам на отдельной строке, соответствующей этому абитуриенту.
#
# Также в конце файла, на отдельной строке, через пробел запишите средние баллы по математике, физике и русскому языку по всем абитуриентам:
#
# Примечание. Для разбиения строки на части по символу ';' можно использовать метод split следующим образом:
#
# print('First;Second-1 Second-2;Third'.split(';'))
#
#
# #### Sample Input:
#
# Петров;85;92;78
#
# Сидоров;100;88;94
#
# Иванов;58;72;85
#
# #### Sample Output:
#
# 85.0
#
# 94.0
#
# 71.666666667
#
# 81.0 84.0 85.666666667

# %%
count = 0
lst = []
with open('dataset_3363_4.txt') as file:
    for string in file:
        string = string.strip().split(';')
        #print(string)
        for i in string[1::]:
            count += int(i)
        print(count/3)
        string.append(count/3)
        #print(string)
        lst.append(string)
        #print(lst)
        count = 0

math = 0
phys = 0
rus = 0
for i in lst:
    math += int(i[1])
    phys += int(i[2])
    rus += int(i[3])
print(math/len(lst), phys/len(lst), rus/len(lst))
# Out:
# 57.666666666666664
# 64.66666666666667
# 62.666666666666664
# 42.666666666666664
# 56.0
# 44.0
# 66.33333333333333
# 57.333333333333336
# 67.0
# 66.0
# 47.0
# 84.66666666666667
# 45.0
# 52.0
# 68.0
# 76.33333333333333
# 85.33333333333333
# 68.0
# 80.33333333333333
# 85.0
# 73.33333333333333
# 55.333333333333336
# 52.333333333333336
# 74.0
# 50.0
# 74.66666666666667
# 85.0
# 48.0
# 83.66666666666667
# 68.33333333333333
# 45.333333333333336
# 68.0
# 43.333333333333336
# 49.666666666666664
# 76.0
# 66.66666666666667
# 59.333333333333336
# 69.66666666666667
# 81.0
# 66.33333333333333
# 52.0
# 68.33333333333333
# 81.33333333333333
# 36.666666666666664
# 61.666666666666664
# 61.0
# 73.33333333333333
# 48.0
# 78.33333333333333
# 67.0
# 40.0
# 76.66666666666667
# 49.666666666666664
# 72.66666666666667
# 67.0
# 64.66666666666667
# 82.33333333333333
# 76.33333333333333
# 73.33333333333333
# 47.0
# 61.666666666666664
# 41.0
# 63.0
# 60.333333333333336
# 46.0
# 52.666666666666664
# 68.66666666666667
# 40.333333333333336
# 49.666666666666664
# 64.33333333333333
# 68.66666666666667
# 68.66666666666667
# 64.33333333333333
# 59.333333333333336
# 46.333333333333336
# 56.333333333333336
# 68.66666666666667
# 47.666666666666664
# 76.0
# 61.666666666666664
# 37.666666666666664
# 64.66666666666667
# 71.33333333333333
# 66.0
# 67.66666666666667
# 54.666666666666664
# 76.66666666666667
# 83.0
# 36.666666666666664
# 68.33333333333333
# 58.0
# 63.0
# 78.66666666666667
# 39.0
# 40.0
# 48.666666666666664
# 54.0
# 37.666666666666664
# 47.666666666666664
# 72.33333333333333
# 71.66666666666667
# 81.33333333333333
# 60.0
# 74.66666666666667
# 75.66666666666667
# 74.0
# 63.0
# 64.66666666666667
# 77.33333333333333
# 52.666666666666664
# 51.666666666666664
# 54.333333333333336
# 77.33333333333333
# 61.333333333333336
# 56.666666666666664
# 53.0
# 68.0
# 67.66666666666667
# 73.33333333333333
# 68.0
# 74.33333333333333
# 74.0
# 37.333333333333336
# 61.333333333333336
# 69.66666666666667
# 36.666666666666664
# 80.0
# 50.333333333333336
# 74.33333333333333
# 90.0
# 48.666666666666664
# 88.0
# 81.66666666666667
# 61.666666666666664
# 78.33333333333333
# 50.333333333333336
# 39.333333333333336
# 38.0
# 82.0
# 56.666666666666664
# 46.666666666666664
# 51.333333333333336
# 70.0
# 74.66666666666667
# 53.0
# 59.666666666666664
# 91.0
# 69.66666666666667
# 71.0
# 37.333333333333336
# 64.0
# 78.0
# 77.66666666666667
# 64.33333333333333
# 60.666666666666664
# 62.666666666666664
# 55.0
# 67.0
# 57.333333333333336
# 33.0
# 76.33333333333333
# 58.546583850931675 66.0 63.53416149068323

# %% [markdown]
# # 3.6 Установка дополнительных модулей (модуля requests)
#
# # Задача 1
#
# Скачайте файл. В нём указан адрес другого файла, который нужно скачать с использованием модуля requests и посчитать число строк в нём.
#
# Используйте функцию get для получения файла (имеет смысл вызвать метод strip к передаваемому параметру, чтобы убрать пробельные символы по краям).
#
# После получения файла вы можете проверить результат, обратившись к полю text. Если результат работы скрипта не принимается, проверьте поле url на правильность. Для подсчёта количества строк разбейте текст с помощью метода splitlines.
#
# В поле ответа введите одно число или отправьте файл, содержащий одно число.

# %%
# with open("C:/Users/admin/Desktop/dataset_3378_2.txt") as file:
import requests
with open("dataset_3378_2.txt") as file:
    s=file.readline().strip()
print('Запрос: ', s, '\n')
r=requests.get(s)
r=r.text
print(r)
r=r.splitlines()
with open("output.txt",'w') as out:
    out.write(str(len(r)))
file.close()
out.close()
# Out:
# Запрос:  https://stepic.org/media/attachments/course67/3.6.2/267.txt
#
# He still did not want outside light. He pulled out his igniter, felt the salamander etched on its silver disc, gave it a flick ...
#
# Two moonstones looked up at him in the light of his small hand-held fire; two pale moonstones buried in a creek of clear water over which the life of the world ran, not touching them.
#
# "Mildred!"
#
# Her face was like a snow-covered island upon which rain might fall, but it felt no rain; over which clouds might pass their moving shadows, but she felt no shadow. There was only the singing of the thimble-wasps in her tamped-shut ears, and her eyes all glass, and breath going in and out, softly, faintly, in and out her nostrils, and her not caring whether it came or went, went or came.
#
# The object he had sent tumbling with his foot now glinted under the edge of his own bed. The small crystal bottle of sleeping tablets which earlier today had been filled with thirty capsules and which now lay uncapped and empty in the light of the tiny flare.
#
# As he stood there the sky over the house screamed. There was a tremendous ripping sound as if two giant hands had torn ten thousand miles of black lines down the seam. Montag was cut in half. He felt his chest chopped down and split apart. The jet bombers going over, going over, going over, one two, one two, one two, six of them, nine of them, twelve of them, one and one and one and another and another and another, did all the screaming for him. He opened his own mouth and let their shriek come down and out between his bared teeth. The house shook. The flare went out in his hand. The moonstones vanished. He felt his hand plunge toward the telephone.
#
# The jets were gone. He felt his lips move, brushing the mouthpiece of the phone. "Emergency hospital."  A terrible whisper.
#
# He felt that the stars had been pulverized by the sound of the black jets and that in the morning the earth would be covered with their dust like a strange snow. That was his idiot thought as he stood shivering in the dark, and let his lips go on moving and moving.
#
# ***
#
# They had this machine. They had two machines, really. One of them slid down into your stomach like a black cobra down an echoing well looking for all the old water and the old time gathered there. It drank up the green matter that flowed to the top in a slow boil.  Did it drink of the darkness? Did it suck out all the poisons accumulated with the years? It fed in silence with an occasional sound of inner suffocation and blind searching. It had an Eye. The impersonal operator of the machine could, by wearing a special optical helmet, gaze into the soul of the person whom he was pumping out. What did the Eye see? He did not say. He saw but did not see what the Eye saw. The  entire operation was not unlike the digging of a trench in one's yard. The woman on the bed was no more than a hard stratum of marble they had reached. Go on, anyway, shove the bore down, slush up the emptiness, if such a thing could be brought out in the throb of the suction snake. The operator stood smoking a cigarette. The other machine was working, too.
#
# The other machine, operated by an equally impersonal fellow in nonstainable reddish-brown coveralls.  This machine pumped all of the blood from the body and replaced it with fresh blood and serum.
#
# "Got to clean 'em out both ways," said the operator, standing over the silent woman. "No use getting the stomach if you don't clean the blood. Leave that stuff in the blood and the blood hits the brain like a mallet, bang, a couple thousand times and the brain just gives up, just quits."
#
# "Stop it!" said Montag.
#
# "I was just sayin'," said the operator.
#
# "Are you done?" said Montag.
#
# They shut the machines up tight. "We're done." His anger did not even touch them. They stood with the cigarette smoke curling around their noses and into their eyes without making them blink or squint.  "That's fifty bucks."
#
# "First, why don't you tell me if she'll be all right?"
#
# "Sure, she'll be okay. We got all the mean stuff right in our suitcase here, it can't get at her now. As I said, you take out the old and put in the new and you're okay. "
#
# "Neither of you is an M.D. Why didn't they send an M.D. from Emergency?"
#
# "Hell!" The operator's cigarette moved on his lip. "We get these cases nine or ten a night. Got so many, starting a few years ago, we had the special machines built. With the optical lens, of course, that was new; the rest is ancient. You don't need an M.D., case like this; all you need is two handymen, clean up the problem in half an hour. Look" -- he started for the door -- "we gotta go. Just had another call on the old ear thimble. Ten blocks from here. Someone else just jumped off the cap of a pillbox. Call if you need us again. Keep her quiet. We got a contrasedative in her. She'll wake up hungry. So long."
#
# And the men with the cigarettes in their straight-lined mouths, the men with the eyes of puff adders, took up their load of machine and tube, their case of liquid melancholy and the slow dark sludge of nameless stuff, and strolled out the door.
#
# Montag sank down into a chair and looked at this woman. Her eyes were closed now, gently, and he put out his hand to feel the warmness of breath on his palm.
#
# "Mildred," he said, at last.
#
# There are too many of us, he thought. There are billions of us and that's too many. Nobody knows anyone. Strangers come and violate you. Strangers come and cut your heart out. Strangers come and take your blood. Good God, who were those men? I never saw them before in my life!
#
# Half an hour passed.
#
# The bloodstream in this woman was new and it seemed to have done a new thing to her. Her cheeks were very pink and her lips were very fresh and full of color and they looked soft and relaxed. Someone else's blood there. If only someone else's flesh and brain and memory. If only they could have taken her mind along to the dry cleaner's and emptied the pockets and steamed and cleansed it and reblocked it and brought it back in the morning. If only ...
#
# He got up and put back the drapes and opened the windows wide to let the night air in. It was two o'clock in the morning. Was it only an hour ago, Clarisse McClellan in the street, and him coming in, and the dark room and his foot kicking the little crystal bottle? Only an hour, but the world had melted down and sprung up in a new and colorless form.
#
# Laughter blew across the moon-colored lawn from the house of Clarisse and her father and mother and the uncle who smiled so quietly and so earnestly.  Above all, their laughter was relaxed and hearty and not forced in any way, coming from the house that was so brightly lit this late at night while all the other houses were kept to themselves in darkness. Montag heard the voices talking, talking, talking, giving, talking, weaving, reweaving their hypnotic web.
#
# Montag moved out through the French windows and crossed the lawn, without even thinking of it. He stood outside the talking house in the shadows, thinking he might even tap on their door and whisper, "Let me come in. I won't say anything. I just want to listen. What is it you're saying?"
#
# But instead he stood there, very cold, his face a mask of ice, listening to a man's voice (the uncle?) moving along at an easy pace:
#
# "Well, after all, this is the age of the disposable tissue. Blow your nose on a person, wad them, flush them away, reach for another, blow, wad, flush.  Everyone using everyone else's coattails. How are you  upposed to root for the home team when you don't even have a program or know the names? For that matter, what color jerseys are they wearing as they trot out on the field?"
#
# Montag moved back to his own house, left the window wide, checked Mildred, tucked the covers about her carefully, and then lay down with the moonlight on his cheekbones and on the frowning ridges in his brow, with the moonlight distilled in each eye to form a silver cataract there.
#
# One drop of rain. Clarisse. Another drop. Mildred. A third. The uncle. A fourth. The fire tonight. One, Clarisse. Two, Mildred. Three, uncle. Four, fire. One, Mildred, two, Clarisse. One, two, three, four, five, Clarisse, Mildred, uncle, fire, sleeping tablets, men disposable tissue, coattails, blow, wad, flush, Clarisse, Mildred, uncle, fire, tablets, tissues, blow, wad, flush.  One, two, three, one, two, three! Rain. The storm.  The uncle laughing. Thunder falling downstairs. The whole world pouring down. The fire gushing up in a volcano. All rushing on down around in a spouting roar and rivering stream toward morning.

# %% [markdown]
# # Задача 2
#
# Имеется набор файлов, каждый из которых, кроме последнего, содержит имя следующего файла.
# Первое слово в тексте последнего файла: "We".
#
# Скачайте предложенный файл. В нём содержится ссылка на первый файл из этого набора.
#
# Все файлы располагаются в каталоге по адресу:
# https://stepic.org/media/attachments/course67/3.6.3/
#
# Загрузите содержимое ﻿последнего файла из набора, как ответ на это задание.

# %%
import requests
with open("dataset_3378_3.txt") as file:
    s=file.readline().strip()
    r=requests.get(s)
while True:
    ss="https://stepic.org/media/attachments/course67/3.6.3/"+r.text
    print('ss: ', ss)
    r=requests.get(ss)
    print("r.text: ", r.text)
    if len(r.text)>20:
        break

with open("output1.txt",'w') as out:
    out.write(str(r.text))
# Out:
# ss:  https://stepic.org/media/attachments/course67/3.6.3/213837.txt
# r.text:  396639.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/396639.txt
# r.text:  835329.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/835329.txt
# r.text:  344063.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/344063.txt
# r.text:  194307.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/194307.txt
# r.text:  195211.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/195211.txt
# r.text:  769171.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/769171.txt
# r.text:  153554.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/153554.txt
# r.text:  680916.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/680916.txt
# r.text:  335636.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/335636.txt
# r.text:  935728.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/935728.txt
# r.text:  081303.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/081303.txt
# r.text:  792633.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/792633.txt
# r.text:  668368.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/668368.txt
# r.text:  647731.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/647731.txt
# r.text:  904392.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/904392.txt
# r.text:  684563.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/684563.txt
# r.text:  997337.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/997337.txt
# r.text:  329467.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/329467.txt
# r.text:  366219.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/366219.txt
# r.text:  730037.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/730037.txt
# r.text:  310230.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/310230.txt
# r.text:  104249.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/104249.txt
# r.text:  382504.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/382504.txt
# r.text:  433681.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/433681.txt
# r.text:  507359.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/507359.txt
# r.text:  293649.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/293649.txt
# r.text:  011641.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/011641.txt
# r.text:  717942.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/717942.txt
# r.text:  258080.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/258080.txt
# r.text:  569395.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/569395.txt
# r.text:  756825.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/756825.txt
# r.text:  921388.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/921388.txt
# r.text:  437007.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/437007.txt
# r.text:  004090.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/004090.txt
# r.text:  362705.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/362705.txt
# r.text:  145282.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/145282.txt
# r.text:  990216.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/990216.txt
# r.text:  645783.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/645783.txt
# r.text:  451262.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/451262.txt
# r.text:  193295.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/193295.txt
# r.text:  777343.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/777343.txt
# r.text:  324603.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/324603.txt
# r.text:  888934.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/888934.txt
# r.text:  138655.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/138655.txt
# r.text:  818396.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/818396.txt
# r.text:  290594.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/290594.txt
# r.text:  478003.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/478003.txt
# r.text:  276687.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/276687.txt
# r.text:  703763.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/703763.txt
# r.text:  712469.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/712469.txt
# r.text:  064418.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/064418.txt
# r.text:  246033.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/246033.txt
# r.text:  356768.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/356768.txt
# r.text:  504290.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/504290.txt
# r.text:  629914.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/629914.txt
# r.text:  062456.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/062456.txt
# r.text:  658472.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/658472.txt
# r.text:  037659.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/037659.txt
# r.text:  351978.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/351978.txt
# r.text:  523822.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/523822.txt
# r.text:  653493.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/653493.txt
# r.text:  859227.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/859227.txt
# r.text:  878358.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/878358.txt
# r.text:  944504.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/944504.txt
# r.text:  457602.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/457602.txt
# r.text:  548571.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/548571.txt
# r.text:  090976.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/090976.txt
# r.text:  965991.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/965991.txt
# r.text:  138128.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/138128.txt
# r.text:  255843.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/255843.txt
# r.text:  797598.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/797598.txt
# r.text:  640003.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/640003.txt
# r.text:  789435.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/789435.txt
# r.text:  181382.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/181382.txt
# r.text:  590526.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/590526.txt
# r.text:  430513.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/430513.txt
# r.text:  182774.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/182774.txt
# r.text:  924794.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/924794.txt
# r.text:  998193.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/998193.txt
# r.text:  770039.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/770039.txt
# r.text:  619504.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/619504.txt
# r.text:  098137.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/098137.txt
# r.text:  874234.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/874234.txt
# r.text:  476929.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/476929.txt
# r.text:  254654.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/254654.txt
# r.text:  972817.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/972817.txt
# r.text:  183249.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/183249.txt
# r.text:  231788.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/231788.txt
# r.text:  238807.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/238807.txt
# r.text:  775176.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/775176.txt
# r.text:  332055.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/332055.txt
# r.text:  971266.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/971266.txt
# r.text:  641342.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/641342.txt
# r.text:  377648.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/377648.txt
# r.text:  665641.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/665641.txt
# r.text:  120842.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/120842.txt
# r.text:  435728.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/435728.txt
# r.text:  860507.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/860507.txt
# r.text:  845049.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/845049.txt
# r.text:  103662.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/103662.txt
# r.text:  989375.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/989375.txt
# r.text:  949525.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/949525.txt
# r.text:  622807.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/622807.txt
# r.text:  441279.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/441279.txt
# r.text:  252484.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/252484.txt
# r.text:  595082.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/595082.txt
# r.text:  942502.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/942502.txt
# r.text:  544418.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/544418.txt
# r.text:  242071.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/242071.txt
# r.text:  696203.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/696203.txt
# r.text:  470997.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/470997.txt
# r.text:  858079.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/858079.txt
# r.text:  299971.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/299971.txt
# r.text:  474312.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/474312.txt
# r.text:  202815.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/202815.txt
# r.text:  192361.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/192361.txt
# r.text:  036087.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/036087.txt
# r.text:  208836.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/208836.txt
# r.text:  057270.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/057270.txt
# r.text:  414940.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/414940.txt
# r.text:  685551.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/685551.txt
# r.text:  877276.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/877276.txt
# r.text:  183839.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/183839.txt
# r.text:  681194.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/681194.txt
# r.text:  268115.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/268115.txt
# r.text:  850395.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/850395.txt
# r.text:  841311.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/841311.txt
# r.text:  318124.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/318124.txt
# r.text:  502298.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/502298.txt
# r.text:  870820.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/870820.txt
# r.text:  886554.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/886554.txt
# r.text:  874723.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/874723.txt
# r.text:  785247.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/785247.txt
# r.text:  743951.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/743951.txt
# r.text:  893121.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/893121.txt
# r.text:  493592.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/493592.txt
# r.text:  043302.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/043302.txt
# r.text:  512901.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/512901.txt
# r.text:  455422.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/455422.txt
# r.text:  405792.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/405792.txt
# r.text:  223561.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/223561.txt
# r.text:  711048.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/711048.txt
# r.text:  986818.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/986818.txt
# r.text:  919305.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/919305.txt
# r.text:  673023.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/673023.txt
# r.text:  195915.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/195915.txt
# r.text:  113918.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/113918.txt
# r.text:  829948.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/829948.txt
# r.text:  407495.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/407495.txt
# r.text:  799448.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/799448.txt
# r.text:  455591.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/455591.txt
# r.text:  046533.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/046533.txt
# r.text:  895838.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/895838.txt
# r.text:  203749.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/203749.txt
# r.text:  897513.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/897513.txt
# r.text:  023903.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/023903.txt
# r.text:  639854.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/639854.txt
# r.text:  767954.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/767954.txt
# r.text:  483260.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/483260.txt
# r.text:  305657.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/305657.txt
# r.text:  113973.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/113973.txt
# r.text:  569665.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/569665.txt
# r.text:  811640.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/811640.txt
# r.text:  627996.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/627996.txt
# r.text:  555691.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/555691.txt
# r.text:  126531.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/126531.txt
# r.text:  434239.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/434239.txt
# r.text:  812997.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/812997.txt
# r.text:  012540.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/012540.txt
# r.text:  457171.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/457171.txt
# r.text:  809767.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/809767.txt
# r.text:  113083.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/113083.txt
# r.text:  168190.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/168190.txt
# r.text:  105218.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/105218.txt
# r.text:  426930.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/426930.txt
# r.text:  839383.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/839383.txt
# r.text:  318610.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/318610.txt
# r.text:  727580.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/727580.txt
# r.text:  966169.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/966169.txt
# r.text:  633699.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/633699.txt
# r.text:  933699.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/933699.txt
# r.text:  254907.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/254907.txt
# r.text:  277257.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/277257.txt
# r.text:  105289.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/105289.txt
# r.text:  618947.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/618947.txt
# r.text:  788422.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/788422.txt
# r.text:  598850.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/598850.txt
# r.text:  218724.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/218724.txt
# r.text:  855788.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/855788.txt
# r.text:  414896.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/414896.txt
# r.text:  086361.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/086361.txt
# r.text:  259720.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/259720.txt
# r.text:  864746.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/864746.txt
# r.text:  213015.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/213015.txt
# r.text:  706951.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/706951.txt
# r.text:  790699.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/790699.txt
# r.text:  556965.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/556965.txt
# r.text:  843911.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/843911.txt
# r.text:  824452.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/824452.txt
# r.text:  558623.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/558623.txt
# r.text:  299517.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/299517.txt
# r.text:  204151.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/204151.txt
# r.text:  864178.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/864178.txt
# r.text:  001410.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/001410.txt
# r.text:  268784.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/268784.txt
# r.text:  413917.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/413917.txt
# r.text:  258819.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/258819.txt
# r.text:  694433.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/694433.txt
# r.text:  376424.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/376424.txt
# r.text:  198564.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/198564.txt
# r.text:  228068.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/228068.txt
# r.text:  417050.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/417050.txt
# r.text:  453058.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/453058.txt
# r.text:  182986.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/182986.txt
# r.text:  237570.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/237570.txt
# r.text:  680981.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/680981.txt
# r.text:  865546.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/865546.txt
# r.text:  367559.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/367559.txt
# r.text:  122687.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/122687.txt
# r.text:  783680.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/783680.txt
# r.text:  626200.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/626200.txt
# r.text:  953943.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/953943.txt
# r.text:  009102.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/009102.txt
# r.text:  882919.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/882919.txt
# r.text:  984198.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/984198.txt
# r.text:  867571.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/867571.txt
# r.text:  889641.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/889641.txt
# r.text:  223919.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/223919.txt
# r.text:  748056.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/748056.txt
# r.text:  577611.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/577611.txt
# r.text:  749540.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/749540.txt
# r.text:  536080.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/536080.txt
# r.text:  351770.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/351770.txt
# r.text:  968708.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/968708.txt
# r.text:  311090.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/311090.txt
# r.text:  239129.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/239129.txt
# r.text:  312237.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/312237.txt
# r.text:  053569.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/053569.txt
# r.text:  678528.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/678528.txt
# r.text:  767429.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/767429.txt
# r.text:  095729.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/095729.txt
# r.text:  452488.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/452488.txt
# r.text:  798915.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/798915.txt
# r.text:  426191.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/426191.txt
# r.text:  067336.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/067336.txt
# r.text:  949017.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/949017.txt
# r.text:  987573.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/987573.txt
# r.text:  843785.txt
# ss:  https://stepic.org/media/attachments/course67/3.6.3/843785.txt
# r.text:  We are the champions, my friends,
# And we'll keep on fighting 'til the end.
# We are the champions.
# We are the champions.
# No time for losers
# 'Cause we are the champions of the world.

# %% [markdown]
# # 3.7 Задачи по материалам недели
#
# Дан файл с таблицей в формате TSV с информацией о росте школьников разных классов.
#
# Напишите программу, которая прочитает этот файл и подсчитает для каждого класса средний рост учащегося.
#
# Файл состоит из набора строк, каждая из которых представляет собой три поля:
# Класс Фамилия Рост
#
# Класс обозначается только числом. Буквенные модификаторы не используются. Номер класса может быть от 1 до 11 включительно. В фамилии нет пробелов, а в качестве роста используется натуральное число, но при подсчёте среднего требуется вычислить значение в виде вещественного числа.
#
# Выводить информацию о среднем росте следует в порядке возрастания номера класса (для классов с первого по одиннадцатый). Если про какой-то класс нет информации, необходимо вывести напротив него прочерк, например:
#
# #### Sample Input:
#
# 6	Вяххи	159
#
# 11	Федотов	172
#
# 7	Бондарев	158
#
# 6	Чайкина	153
#
# #### Sample Output:
#
# 1 -
#
# 2 -
#
# 3 -
#
# 4 -
#
# 5 -
#
# 6 156.0
#
# 7 158.0
#
# 8 -
#
# 9 -
#
# 10 -
#
# 11 172.0

# %%
setClasses = tuple(str(i) for i in range(1, 12))
dictHeight = dict.fromkeys(setClasses, 0)
dictCount = dict.fromkeys(setClasses, 0)

with open('dataset_3380_5.txt', encoding='UTF-8') as inf:
    for line in inf:
        lst = line.strip().split('\t')
        dictHeight[lst[0]] += float(lst[2])
        dictCount[lst[0]] += 1

for i in setClasses:
    if dictHeight[i] == 0:
        d = '-'
    else:
        d = str(dictHeight[i] / dictCount[i])
    print(i + ' ' + d)
# Out:
# 1 126.75
# 2 130.0
# 3 134.71428571428572
# 4 140.0
# 5 143.42857142857142
# 6 155.5
# 7 159.0
# 8 163.66666666666666
# 9 170.83333333333334
# 10 171.83333333333334
# 11 176.5
